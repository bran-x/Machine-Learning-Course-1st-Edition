# %% [markdown]
# ## Gradient Tree Boosting

# %% [markdown]
# ## 1. Dataset

# %%
from sklearn.datasets import make_classification
X,Y = make_classification(n_samples=1000, n_features=8,n_informative=8, n_redundant=0, n_repeated=0, n_classes=5, n_clusters_per_class=1)

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## 2. Modelo

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()

# %%
a = cross_val_score(gbc,X,Y, cv=5)

# %%
a
# Out:
# array([0.83 , 0.835, 0.81 , 0.855, 0.785])

# %% [markdown]
# Comparacion con AdaBoost, max_depth=3

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
abc = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5),n_estimators=100, learning_rate=0.1)

# %%
a = cross_val_score(abc,X,Y, cv=5)

# %%
a
# Out:
# array([0.79 , 0.82 , 0.765, 0.835, 0.785])
